# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
# !pwd
# Out:
# /Users/juliewang/DS-SF-36/classes/03/notebooks

# %%
df = pd.read_csv(os.path.join('..', '/lab_WHEL_file_2.csv')
# Out:
#   File "<ipython-input-9-f86be9dcce7f>", line 1
#     df = pd.read_csv(os.path.join('..', '/lab_WHEL_file_2.csv')
#                                                                ^
# SyntaxError: unexpected EOF while parsing

# %%
# !ls ../lab_WHEL_file_2.csv
# Out:
# ls: ../lab_WHEL_file_2.csv: No such file or directory

# %%
# !cd ~

# %%
# !ls -l
# Out:
# total 1368
# -rw-r--r--  1 juliewang  staff    1076 Jul  8 20:33 Untitled.ipynb
# -rw-r--r--  1 juliewang  staff    2192 Jul  8 20:44 Untitled1.ipynb
# -rwxr-xr-x  1 juliewang  staff   33572 Jul  6 23:05 assignment-03-pandas-answer-key.ipynb
# -rwxr-xr-x  1 juliewang  staff   11098 Jun 28 18:36 assignment-03-pandas-starter-code.ipynb
# -rwxr-xr-x  1 juliewang  staff  207717 Jul  8 18:55 codealong-03-pandas-answer-key.ipynb
# -rwxr-xr-x  1 juliewang  staff  430471 Jul  6 20:18 codealong-03-pandas-starter-code.ipynb

# %%
# !cd ~

# %%
# !cd ~

# %%
# !ls -l
# Out:
# total 1368
# -rw-r--r--  1 juliewang  staff    1076 Jul  8 20:33 Untitled.ipynb
# -rw-r--r--  1 juliewang  staff    2192 Jul  8 20:44 Untitled1.ipynb
# -rwxr-xr-x  1 juliewang  staff   33572 Jul  6 23:05 assignment-03-pandas-answer-key.ipynb
# -rwxr-xr-x  1 juliewang  staff   11098 Jun 28 18:36 assignment-03-pandas-starter-code.ipynb
# -rwxr-xr-x  1 juliewang  staff  207717 Jul  8 18:55 codealong-03-pandas-answer-key.ipynb
# -rwxr-xr-x  1 juliewang  staff  430471 Jul  6 20:18 codealong-03-pandas-starter-code.ipynb

# %%
# !ls ../lab_WHEL_file_2.csv
# Out:
# ../lab_WHEL_file_2.csv

# %%
df = pd.read_csv(os.path.join('..', 'lab_WHEL_file_2.csv'))

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 0      1002          1          2      2           3       ...
# 1      1003          1          2      2           3       ...
# 2      1005          2          1      1           3       ...
# 3      1007          2          1      2           4       ...
# 4      1008          2          1      1           3       ...
# 5      1009          2          1      1           3       ...
# 6      1010          2          1      2           3       ...
# 7      1011          1          2      2           1       ...
# 8      1012          1          2      1           3       ...
# 9      1015          2          1      2           3       ...
# ...     ...        ...        ...    ...         ...       ...
# 3078  13236          1          2      1           3       ...
# 3079  13237          2          1      1           3       ...
# 3080  13238          2          1      2           3       ...
# ...

# %%
df.head(5)
# Out:
#      ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 0  1002          1          2      2           3       ...
# 1  1003          1          2      2           3       ...
# 2  1005          2          1      1           3       ...
# 3  1007          2          1      2           4       ...
# 4  1008          2          1      1           3       ...
#
#    Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 0             -9               -9          1              1               1
# 1             -9               -9          2              1               1
# 2             -9               -9          2              3               1
# 3             -9               -9          2              1               1
# 4             -9               -9          2              1               1
#
# [5 rows x 22 columns]

# %%
df.tail(5)
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 3083  13241          1          2      1           4       ...
# 3084  13242          2          1      2           3       ...
# 3085  13243          2          2      2           2       ...
# 3086  13244          1          2      2           3       ...
# 3087  13245          1          2      2           1       ...
#
#       Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 3083            120               66          2              1               1
# 3084            113               75          2              1               2
# 3085            154               85          2              2               4
# 3086            113               75          3              2               4
# 3087            110               79          2              2               4
#
# [5 rows x 22 columns]

# %%
df.isnull()
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...         \
# 0     False      False      False  False       False       ...
# 1     False      False      False  False       False       ...
# 2     False      False      False  False       False       ...
# 3     False      False      False  False       False       ...
# 4     False      False      False  False       False       ...
# 5     False      False      False  False       False       ...
# 6     False      False      False  False       False       ...
# 7     False      False      False  False       False       ...
# 8     False      False      False  False       False       ...
# 9     False      False      False  False       False       ...
# ...     ...        ...        ...    ...         ...       ...
# 3078  False      False      False  False       False       ...
# 3079  False      False      False  False       False       ...
# 3080  False      False      False  False       False       ...
# ...

# %%
df.isnull().sum()
# Out:
# ID                  0
# Lump/Mast           0
# Radiation           0
# Chemo               0
# Tumor Type          0
# Estr Recep          0
# Prog Recep          0
# Node Exam           0
# Node Pos            1
# Stage               0
#                    ..
# Weight              0
# BMI                 0
# Waist              18
# Hip                18
# Pulse               0
# Bld Pres -Sys       0
# Bld Pres - Dias     0
# Menopause           0
# Anti-Estr Use       0
# Anti-Estro Type     0
# Length: 22, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 41L

# %%
df.shape
# Out:
# (3088, 22)

# %%
df[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-29-9ae93f22b889> in <module>()
# ----> 1 df[0]
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2060             return self._getitem_multilevel(key)
#    2061         else:
# -> 2062             return self._getitem_column(key)
#    2063
#    2064     def _getitem_column(self, key):
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    2067         # get column
#    2068         if self.columns.is_unique:
# -> 2069             return self._get_item_cache(key)
#    2070
#    2071         # duplicate columns & possible reduce dimensionality
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
#    1532         res = cache.get(item)
# ...

# %%
df.shape[0]
# Out:
# 3088

# %%
df.shape[1]
# Out:
# 22

# %%
df.shape
# Out:
# (3088, 22)

# %%
len(df)
# Out:
# 3088

# %%
df.dtypes
# Out:
# ID                   int64
# Lump/Mast            int64
# Radiation            int64
# Chemo                int64
# Tumor Type           int64
# Estr Recep           int64
# Prog Recep           int64
# Node Exam            int64
# Node Pos           float64
# Stage               object
#                     ...
# Weight             float64
# BMI                float64
# Waist              float64
# Hip                float64
# Pulse                int64
# Bld Pres -Sys        int64
# Bld Pres - Dias      int64
# Menopause            int64
# Anti-Estr Use        int64
# Anti-Estro Type      int64
# Length: 22, dtype: object

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3088, step=1)

# %%
df.columns
# Out:
# Index([u'ID', u'Lump/Mast', u'Radiation', u'Chemo', u'Tumor Type',
#        u'Estr Recep', u'Prog Recep', u'Node Exam', u'Node Pos', u'Stage',
#        u'Tumor Size', u'Height', u'Weight', u'BMI', u'Waist', u'Hip', u'Pulse',
#        u'Bld Pres -Sys', u'Bld Pres - Dias', u'Menopause', u'Anti-Estr Use',
#        u'Anti-Estro Type'],
#       dtype='object')

# %%
df
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 0      1002          1          2      2           3       ...
# 1      1003          1          2      2           3       ...
# 2      1005          2          1      1           3       ...
# 3      1007          2          1      2           4       ...
# 4      1008          2          1      1           3       ...
# 5      1009          2          1      1           3       ...
# 6      1010          2          1      2           3       ...
# 7      1011          1          2      2           1       ...
# 8      1012          1          2      1           3       ...
# 9      1015          2          1      2           3       ...
# ...     ...        ...        ...    ...         ...       ...
# 3078  13236          1          2      1           3       ...
# 3079  13237          2          1      1           3       ...
# 3080  13238          2          1      2           3       ...
# ...

# %%
df.columns[3]
# Out:
# 'Chemo'

# %%
df.columns
# Out:
# Index([u'ID', u'Lump/Mast', u'Radiation', u'Chemo', u'Tumor Type',
#        u'Estr Recep', u'Prog Recep', u'Node Exam', u'Node Pos', u'Stage',
#        u'Tumor Size', u'Height', u'Weight', u'BMI', u'Waist', u'Hip', u'Pulse',
#        u'Bld Pres -Sys', u'Bld Pres - Dias', u'Menopause', u'Anti-Estr Use',
#        u'Anti-Estro Type'],
#       dtype='object')

# %%
df.columns[0]
# Out:
# 'ID'

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df[['ID', 'Lump/Mast']]
# Out:
#          ID  Lump/Mast
# 0      1002          1
# 1      1003          1
# 2      1005          2
# 3      1007          2
# 4      1008          2
# 5      1009          2
# 6      1010          2
# 7      1011          1
# 8      1012          1
# 9      1015          2
# ...     ...        ...
# 3078  13236          1
# 3079  13237          2
# 3080  13238          2
# 3081  13239          1
# 3082  13240          2
# 3083  13241          1
# 3084  13242          2
# 3085  13243          2
# 3086  13244          1
# 3087  13245          1
#
# [3088 rows x 2 columns]

# %%
df['Lump/Mast']
# Out:
# 0       1
# 1       1
# 2       2
# 3       2
# 4       2
# 5       2
# 6       2
# 7       1
# 8       1
# 9       2
#        ..
# 3078    1
# 3079    2
# 3080    2
# 3081    1
# 3082    2
# 3083    1
# 3084    2
# 3085    2
# 3086    1
# 3087    1
# Name: Lump/Mast, Length: 3088, dtype: int64

# %%
df[:5]
# Out:
#      ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 0  1002          1          2      2           3       ...
# 1  1003          1          2      2           3       ...
# 2  1005          2          1      1           3       ...
# 3  1007          2          1      2           4       ...
# 4  1008          2          1      1           3       ...
#
#    Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 0             -9               -9          1              1               1
# 1             -9               -9          2              1               1
# 2             -9               -9          2              3               1
# 3             -9               -9          2              1               1
# 4             -9               -9          2              1               1
#
# [5 rows x 22 columns]

# %%
df[-5:]
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 3083  13241          1          2      1           4       ...
# 3084  13242          2          1      2           3       ...
# 3085  13243          2          2      2           2       ...
# 3086  13244          1          2      2           3       ...
# 3087  13245          1          2      2           1       ...
#
#       Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 3083            120               66          2              1               1
# 3084            113               75          2              1               2
# 3085            154               85          2              2               4
# 3086            113               75          3              2               4
# 3087            110               79          2              2               4
#
# [5 rows x 22 columns]

# %%
df[[6,7,12]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-53-21c15eef4076> in <module>()
# ----> 1 df[[6,7,12]]
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    2054         if isinstance(key, (Series, np.ndarray, Index, list)):
#    2055             # either boolean or fancy integer index
# -> 2056             return self._getitem_array(key)
#    2057         elif isinstance(key, DataFrame):
#    2058             return self._getitem_frame(key)
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    2098             return self.take(indexer, axis=0, convert=False)
#    2099         else:
# -> 2100             indexer = self.loc._convert_to_indexer(key, axis=1)
#    2101             return self.take(indexer, axis=1, convert=True)
#    2102
#
# ...

# %%
df.iloc[[6, 7, 12]]
# Out:
#       ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 6   1010          2          1      2           3       ...
# 7   1011          1          2      2           1       ...
# 12  1019          1          2      1           3       ...
#
#     Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 6              -9               -9          2              1               1
# 7              -9               -9          3              2               4
# 12             -9               -9          2              1               1
#
# [3 rows x 22 columns]

# %%
df.iloc[6,7,12]]
# Out:
#   File "<ipython-input-55-314d5a309a20>", line 1
#     df.iloc[6,7,12]]
#                    ^
# SyntaxError: invalid syntax

# %%
df.iloc[[6,7,12]]
# Out:
#       ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 6   1010          2          1      2           3       ...
# 7   1011          1          2      2           1       ...
# 12  1019          1          2      1           3       ...
#
#     Bld Pres -Sys  Bld Pres - Dias  Menopause  Anti-Estr Use Anti-Estro Type
# 6              -9               -9          2              1               1
# 7              -9               -9          3              2               4
# 12             -9               -9          2              1               1
#
# [3 rows x 22 columns]

# %%
df = df.set_index('ID')

# %%
df.index
# Out:
# Int64Index([ 1002,  1003,  1005,  1007,  1008,  1009,  1010,  1011,  1012,
#              1015,
#             ...
#             13236, 13237, 13238, 13239, 13240, 13241, 13242, 13243, 13244,
#             13245],
#            dtype='int64', name=u'ID', length=3088)

# %%
df
# Out:
#        Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                               ...
# 1002           1          2      2           3           1       ...
# 1003           1          2      2           3           1       ...
# 1005           2          1      1           3           3       ...
# 1007           2          1      2           4           0       ...
# 1008           2          1      1           3           1       ...
# 1009           2          1      1           3           1       ...
# 1010           2          1      2           3           1       ...
# 1011           1          2      2           1           0       ...
# 1012           1          2      1           3           1       ...
# 1015           2          1      2           3           1       ...
# ...          ...        ...    ...         ...         ...       ...
# ...

# %%
df.iloc['1005']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-eb08f8c6fcc0> in <module>()
# ----> 1 df.iloc['1005']
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1740         # a single integer
#    1741         else:
# -> 1742             key = self._convert_scalar_indexer(key, axis)
#    1743
#    1744             if not is_integer(key):
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_scalar_indexer(self, key, axis)
# ...

# %%
df.iloc[['1005']]
# Out:
#       Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                              ...
# 5046          1          2      1           3           1       ...
#
#       Bld Pres -Sys  Bld Pres - Dias  Menopause Anti-Estr Use Anti-Estro Type
# ID
# 5046             -9               -9          2             1               1
#
# [1 rows x 21 columns]

# %%
df.loc[['1005']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-f7289a1cd833> in <module>()
# ----> 1 df.loc[['1005']]
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1539                     raise ValueError('Cannot index with multidimensional key')
#    1540
# -> 1541                 return self._getitem_iterable(key, axis=axis)
#    1542
#    1543             # nested tuple slicing
#
# ...

# %%
df.loc[1005]
# Out:
# Lump/Mast                2
# Radiation                1
# Chemo                    1
# Tumor Type               3
# Estr Recep               3
# Prog Recep               3
# Node Exam               29
# Node Pos                 0
# Stage                   II
# Tumor Size             2.5
#                     ...
# Weight               68.63
# BMI                32.4181
# Waist                   92
# Hip                    110
# Pulse                   -9
# Bld Pres -Sys           -9
# Bld Pres - Dias         -9
# Menopause                2
# Anti-Estr Use            3
# Anti-Estro Type          1
# Name: 1005, Length: 21, dtype: object

# %%
df.loc[1005]
# Out:
# Lump/Mast                2
# Radiation                1
# Chemo                    1
# Tumor Type               3
# Estr Recep               3
# Prog Recep               3
# Node Exam               29
# Node Pos                 0
# Stage                   II
# Tumor Size             2.5
#                     ...
# Weight               68.63
# BMI                32.4181
# Waist                   92
# Hip                    110
# Pulse                   -9
# Bld Pres -Sys           -9
# Bld Pres - Dias         -9
# Menopause                2
# Anti-Estr Use            3
# Anti-Estro Type          1
# Name: 1005, Length: 21, dtype: object

# %%
df.loc[[1005]]
# Out:
#       Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                              ...
# 1005          2          1      1           3           3       ...
#
#       Bld Pres -Sys  Bld Pres - Dias  Menopause Anti-Estr Use Anti-Estro Type
# ID
# 1005             -9               -9          2             3               1
#
# [1 rows x 21 columns]

# %%
df.iloc[[1005, 1006]]
# Out:
#       Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                              ...
# 5046          1          2      1           3           1       ...
# 5047          2          1      2           2           0       ...
#
#       Bld Pres -Sys  Bld Pres - Dias  Menopause Anti-Estr Use Anti-Estro Type
# ID
# 5046             -9               -9          2             1               1
# 5047             -9               -9          2             2               4
#
# [2 rows x 21 columns]

# %%
df.loc[1005].chem
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-ac3f2c3cda63> in <module>()
# ----> 1 df.loc[1005].chem
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'chem'

# %%
df.loc[1005]chemo
# Out:
#   File "<ipython-input-69-d869dfa60e1d>", line 1
#     df.loc[1005]chemo
#                     ^
# SyntaxError: invalid syntax

# %%
df.loc[ 1005 ].chemo
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-72-3770301b6cac> in <module>()
# ----> 1 df.loc[ 1005 ].chemo
#
# /Users/juliewang/anaconda/lib/python2.7/site-packages/pandas/core/generic.pyc in __getattr__(self, name)
#    2968             if name in self._info_axis:
#    2969                 return self[name]
# -> 2970             return object.__getattribute__(self, name)
#    2971
#    2972     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'chemo'

# %%
df.loc[1005]
# Out:
# Lump/Mast                2
# Radiation                1
# Chemo                    1
# Tumor Type               3
# Estr Recep               3
# Prog Recep               3
# Node Exam               29
# Node Pos                 0
# Stage                   II
# Tumor Size             2.5
#                     ...
# Weight               68.63
# BMI                32.4181
# Waist                   92
# Hip                    110
# Pulse                   -9
# Bld Pres -Sys           -9
# Bld Pres - Dias         -9
# Menopause                2
# Anti-Estr Use            3
# Anti-Estro Type          1
# Name: 1005, Length: 21, dtype: object

# %%
df.loc[1005].Chemo
# Out:
# 1

# %%
df.['BMI']
# Out:
#   File "<ipython-input-87-e98ab6863923>", line 1
#     df.['BMI']
#        ^
# SyntaxError: invalid syntax

# %%
df [ (df.BMI >= 40)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-81-2145386e0932> in <module>()
# ----> 1 df [ (df.BMI >= 40)]
#
# AttributeError: 'list' object has no attribute 'BMI'

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-6a4642092433> in <module>()
# ----> 1 df.columns
#
# AttributeError: 'list' object has no attribute 'columns'
