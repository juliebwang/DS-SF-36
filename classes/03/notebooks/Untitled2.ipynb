# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 20)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
df = pd.read_csv(os.path.join('..', 'lab_WHEL_file_2.csv'))

# %%
df
# Out:
#          ID  Lump/Mast  Radiation  Chemo  Tumor Type       ...        \
# 0      1002          1          2      2           3       ...
# 1      1003          1          2      2           3       ...
# 2      1005          2          1      1           3       ...
# 3      1007          2          1      2           4       ...
# 4      1008          2          1      1           3       ...
# 5      1009          2          1      1           3       ...
# 6      1010          2          1      2           3       ...
# 7      1011          1          2      2           1       ...
# 8      1012          1          2      1           3       ...
# 9      1015          2          1      2           3       ...
# ...     ...        ...        ...    ...         ...       ...
# 3078  13236          1          2      1           3       ...
# 3079  13237          2          1      1           3       ...
# 3080  13238          2          1      2           3       ...
# ...

# %%
df['BMI']
# Out:
# 0       23.0697
# 1       23.4375
# 2       32.4181
# 3       23.3808
# 4       25.4737
# 5       31.5568
# 6       31.4871
# 7       23.0469
# 8       27.2304
# 9       27.9121
#          ...
# 3078    28.7769
# 3079    24.9487
# 3080    22.0535
# 3081    38.1543
# 3082    26.5097
# 3083    33.4444
# 3084    22.8010
# 3085    34.4635
# 3086    29.7160
# 3087    24.8016
# Name: BMI, Length: 3088, dtype: float64

# %%
df = df.set_index('ID')

# %%
df.loc[1005].BMI
# Out:
# 32.418100000000003

# %%
df.BMI < 30
# Out:
# ID
# 1002      True
# 1003      True
# 1005     False
# 1007      True
# 1008      True
# 1009     False
# 1010     False
# 1011      True
# 1012      True
# 1015      True
#          ...
# 13236     True
# 13237     True
# 13238     True
# 13239    False
# 13240     True
# 13241    False
# 13242     True
# 13243    False
# 13244     True
# 13245     True
# Name: BMI, Length: 3088, dtype: bool

# %%
df [ (df.BMI < 30)].shape
# Out:
# (2285, 21)

# %%
df['BMI']
# Out:
# ID
# 1002     23.0697
# 1003     23.4375
# 1005     32.4181
# 1007     23.3808
# 1008     25.4737
# 1009     31.5568
# 1010     31.4871
# 1011     23.0469
# 1012     27.2304
# 1015     27.9121
#           ...
# 13236    28.7769
# 13237    24.9487
# 13238    22.0535
# 13239    38.1543
# 13240    26.5097
# 13241    33.4444
# 13242    22.8010
# 13243    34.4635
# 13244    29.7160
# 13245    24.8016
# Name: BMI, Length: 3088, dtype: float64

# %%
df.['BMI'].shape
# Out:
#   File "<ipython-input-12-6a6f727a4acf>", line 1
#     df.['BMI'].shape
#        ^
# SyntaxError: invalid syntax

# %%
df.shape
# Out:
# (3088, 21)

# %%
df [(df.BMI < 30)]
# Out:
#        Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                               ...
# 1002           1          2      2           3           1       ...
# 1003           1          2      2           3           1       ...
# 1007           2          1      2           4           0       ...
# 1008           2          1      1           3           1       ...
# 1011           1          2      2           1           0       ...
# 1012           1          2      1           3           1       ...
# 1015           2          1      2           3           1       ...
# 1017           1          2      2           3           0       ...
# 1018           2          1      2           2           1       ...
# 1019           1          2      1           3           1       ...
# ...          ...        ...    ...         ...         ...       ...
# ...

# %%
df [(df.BMI < 30)].shape
# Out:
# (2285, 21)

# %%
df.BMI
# Out:
# ID
# 1002     23.0697
# 1003     23.4375
# 1005     32.4181
# 1007     23.3808
# 1008     25.4737
# 1009     31.5568
# 1010     31.4871
# 1011     23.0469
# 1012     27.2304
# 1015     27.9121
#           ...
# 13236    28.7769
# 13237    24.9487
# 13238    22.0535
# 13239    38.1543
# 13240    26.5097
# 13241    33.4444
# 13242    22.8010
# 13243    34.4635
# 13244    29.7160
# 13245    24.8016
# Name: BMI, Length: 3088, dtype: float64

# %%
df.BMI.shape
# Out:
# (3088,)

# %%
df.columns
# Out:
# Index([u'Lump/Mast', u'Radiation', u'Chemo', u'Tumor Type', u'Estr Recep',
#        u'Prog Recep', u'Node Exam', u'Node Pos', u'Stage', u'Tumor Size',
#        u'Height', u'Weight', u'BMI', u'Waist', u'Hip', u'Pulse',
#        u'Bld Pres -Sys', u'Bld Pres - Dias', u'Menopause', u'Anti-Estr Use',
#        u'Anti-Estro Type'],
#       dtype='object')

# %%
df [ (df.BMI < 30) & (df.Radiation == 2)]
# Out:
#        Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                               ...
# 1002           1          2      2           3           1       ...
# 1003           1          2      2           3           1       ...
# 1011           1          2      2           1           0       ...
# 1012           1          2      1           3           1       ...
# 1017           1          2      2           3           0       ...
# 1019           1          2      1           3           1       ...
# 1020           1          2      2           3           0       ...
# 1026           2          2      2           3           1       ...
# 1027           2          2      1           3           1       ...
# 1028           1          2      1           3           1       ...
# ...          ...        ...    ...         ...         ...       ...
# ...

# %%
df [ (df.BMI < 30) & (df.Radiation == 2)].shape
# Out:
# (1401, 21)

# %%
len(df [ (df.BMI < 30) & (df.Radiation == 2)])
# Out:
# 1401

# %%
df [ (df.BMI < 30) & (df.Radiation == 2)].isnull()
# Out:
#        Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...         \
# ID                                                               ...
# 1002       False      False  False       False       False       ...
# 1003       False      False  False       False       False       ...
# 1011       False      False  False       False       False       ...
# 1012       False      False  False       False       False       ...
# 1017       False      False  False       False       False       ...
# 1019       False      False  False       False       False       ...
# 1020       False      False  False       False       False       ...
# 1026       False      False  False       False       False       ...
# 1027       False      False  False       False       False       ...
# 1028       False      False  False       False       False       ...
# ...          ...        ...    ...         ...         ...       ...
# ...

# %%
df [ (df.BMI < 30) & (df.Radiation == 2)].isnull().sum()
# Out:
# Lump/Mast           0
# Radiation           0
# Chemo               0
# Tumor Type          0
# Estr Recep          0
# Prog Recep          0
# Node Exam           0
# Node Pos            1
# Stage               0
# Tumor Size          3
#                    ..
# Weight              0
# BMI                 0
# Waist              12
# Hip                12
# Pulse               0
# Bld Pres -Sys       0
# Bld Pres - Dias     0
# Menopause           0
# Anti-Estr Use       0
# Anti-Estro Type     0
# Length: 21, dtype: int64

# %%
df [ (df.BMI < 30) & (df.Radiation == 2)].isnull().sum().sum()
# Out:
# 28L

# %%
df[df.BMI < 30][df.Radiation == 2]
# Out:
# /Users/juliewang/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
#        Lump/Mast  Radiation  Chemo  Tumor Type  Estr Recep       ...        \
# ID                                                               ...
# 1002           1          2      2           3           1       ...
# 1003           1          2      2           3           1       ...
# 1011           1          2      2           1           0       ...
# 1012           1          2      1           3           1       ...
# 1017           1          2      2           3           0       ...
# 1019           1          2      1           3           1       ...
# 1020           1          2      2           3           0       ...
# 1026           2          2      2           3           1       ...
# 1027           2          2      1           3           1       ...
# ...

# %%
df[df.BMI < 30][df.Radiation == 2].shape
# Out:
# /Users/juliewang/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """Entry point for launching an IPython kernel.
# (1401, 21)

# %%
df[(df.BMI < 30) & (df.Radiation == 2)] [['Menopause']]
# Out:
#        Menopause
# ID
# 1002           1
# 1003           2
# 1011           3
# 1012           2
# 1017           3
# 1019           2
# 1020           2
# 1026           2
# 1027           2
# 1028           2
# ...          ...
# 13222          2
# 13225          2
# 13228          2
# 13229          2
# 13230          2
# 13233          2
# 13235          2
# 13236          2
# 13244          3
# 13245          2
#
# [1401 rows x 1 columns]

# %%
df [(df.BMI < 30) & (df.Radiation == 2)]['Menopause']
# Out:
# ID
# 1002     1
# 1003     2
# 1011     3
# 1012     2
# 1017     3
# 1019     2
# 1020     2
# 1026     2
# 1027     2
# 1028     2
#         ..
# 13222    2
# 13225    2
# 13228    2
# 13229    2
# 13230    2
# 13233    2
# 13235    2
# 13236    2
# 13244    3
# 13245    2
# Name: Menopause, Length: 1401, dtype: int64

# %%
df [(df.BMI < 30) & (df.Radiation == 2)][['Menopause']]
# Out:
#        Menopause
# ID
# 1002           1
# 1003           2
# 1011           3
# 1012           2
# 1017           3
# 1019           2
# 1020           2
# 1026           2
# 1027           2
# 1028           2
# ...          ...
# 13222          2
# 13225          2
# 13228          2
# 13229          2
# 13230          2
# 13233          2
# 13235          2
# 13236          2
# 13244          3
# 13245          2
#
# [1401 rows x 1 columns]

# %%
df.Menopause
# Out:
# ID
# 1002     1
# 1003     2
# 1005     2
# 1007     2
# 1008     2
# 1009     3
# 1010     2
# 1011     3
# 1012     2
# 1015     2
#         ..
# 13236    2
# 13237    2
# 13238    2
# 13239    2
# 13240    2
# 13241    2
# 13242    2
# 13243    2
# 13244    3
# 13245    2
# Name: Menopause, Length: 3088, dtype: int64

# %%
df['Menopause']
# Out:
# ID
# 1002     1
# 1003     2
# 1005     2
# 1007     2
# 1008     2
# 1009     3
# 1010     2
# 1011     3
# 1012     2
# 1015     2
#         ..
# 13236    2
# 13237    2
# 13238    2
# 13239    2
# 13240    2
# 13241    2
# 13242    2
# 13243    2
# 13244    3
# 13245    2
# Name: Menopause, Length: 3088, dtype: int64

# %%
df [(df.BMI < 30) & (df.Radiation == 2)].Menopause
# Out:
# ID
# 1002     1
# 1003     2
# 1011     3
# 1012     2
# 1017     3
# 1019     2
# 1020     2
# 1026     2
# 1027     2
# 1028     2
#         ..
# 13222    2
# 13225    2
# 13228    2
# 13229    2
# 13230    2
# 13233    2
# 13235    2
# 13236    2
# 13244    3
# 13245    2
# Name: Menopause, Length: 1401, dtype: int64

# %%
df [(df.BMI < 30) & (df.Radiation == 2)][['Menopause']]
# Out:
#        Menopause
# ID
# 1002           1
# 1003           2
# 1011           3
# 1012           2
# 1017           3
# 1019           2
# 1020           2
# 1026           2
# 1027           2
# 1028           2
# ...          ...
# 13222          2
# 13225          2
# 13228          2
# 13229          2
# 13230          2
# 13233          2
# 13235          2
# 13236          2
# 13244          3
# 13245          2
#
# [1401 rows x 1 columns]

# %%
df_base = pd.read_csv(os.path.join('..', 'baseline.csv'), index_col = 'ID')

# %%
df_lab = pd.read_csv(os.path.join('..', 'lab_WHEL_file_2.csv'), index_col = 'ID')

# %%
df = df_base()
